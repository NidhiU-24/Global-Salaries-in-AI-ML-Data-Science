# %% [markdown]
# ### There are three type of Data Analysis to focus on in this project:
#
# *   Descriptive Analysis
# *   Exploratory Analysis
# *   Diagnostic Analysis
#
# #### I will not be having any requirements for number of charts or what type of analysis visualizations that I want to see. I am leaving that up to your discretion. I DO expect that it is thorough and that you have unique, insightful, and clean visualizations that hit all three types of data analysis. I have given a description in each section header to guide you.
#
#
# Citation:https://www.simplilearn.com/data-analysis-methods-process-types-article

# %% [markdown]
# ## Name(s): Nidhi Nityanand Uchil, Sri Sai Tarun, Tanaya Kondejkar
# ## Due Date: 20th November 2023
# ## Class and Professor: Computation and Visualization for Analytics , Satwik S. Kamarthi

# %%
#import necessary libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1= pd.read_csv('/content/drive/MyDrive/CVA/salaries updated.csv')

# %% [markdown]
# # **Descriptive Analysis**
#
# "Descriptive Analysis involves summarizing and describing the main features of the dataset. It focuses on organizing and presenting the data in a meaningful way, often using measures such as mean, median, mode, and standard deviation. It provides an overview of the data and helps identify patterns or trends."

# %%
# 1. Basic information about the dataset
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6477 entries, 0 to 6476
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           6477 non-null   int64
#  1   experience_level    6477 non-null   object
#  2   employment_type     6477 non-null   object
#  3   job_title           6477 non-null   object
#  4   salary              6477 non-null   int64
#  5   salary_currency     6477 non-null   object
#  6   salary_in_usd       6477 non-null   int64
#  7   employee_residence  6477 non-null   object
#  8   remote_ratio        6477 non-null   int64
#  9   company_location    6477 non-null   object
#  10  company_size        6477 non-null   object
#  11  Python              6477 non-null   object
#  12  SQL                 6477 non-null   object
#  13  AWS                 6477 non-null   object
#  14  PyTorch             6477 non-null   object
# ...

# %%
# 2. summary statistics for numerical columns
print(data1.describe())
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  6477.000000  6.477000e+03    6477.000000   6477.000000
# mean   2022.739694  1.634388e+05  147632.944419     39.262004
# std       0.519408  4.369684e+05   60905.090297     48.408380
# min    2020.000000  1.500000e+04   15000.000000      0.000000
# 25%    2023.000000  1.050000e+05  105000.000000      0.000000
# 50%    2023.000000  1.421270e+05  141525.000000      0.000000
# 75%    2023.000000  1.850000e+05  185000.000000    100.000000
# max    2023.000000  3.040000e+07  430967.000000    100.000000

# %%
# 3. Average salary by employment type
average_salary_by_employment = data1.groupby('employment_type')['salary'].mean().sort_values()
average_salary_by_employment.plot(kind='bar')
plt.title('Average Salary by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# # **Exploratory Analysis**
# "Exploratory Analysis focuses on exploring and understanding the data without preconceived hypotheses. It involves visualizations, summary statistics, and data profiling techniques to uncover patterns, relationships, and interesting features. It helps generate hypotheses for further analysis"

# %%
# 1. Distribution of experience levels
plt.figure(figsize=(10, 6))
sns.countplot(x='experience_level', data=data1, palette='viridis')
plt.title('Distribution of Experience Levels')
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.show()

# %%
# 2. Salary Distribution
plt.figure(figsize=(14, 8))
sns.boxplot(x='job_title', y='salary', data=data1)
plt.title('Salary Distribution by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Salary')
##plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# 3. Distribution of Experience Levels
experience_counts = data1['experience_level'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(experience_counts, labels=experience_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99','#ffcc99','#ff6666'])
plt.title('Distribution of Experience Levels')
plt.show()

# %% [markdown]
# The overall amount of work done remotely, possible values are as follows:
# 1. 0- No remote work (less than 20%)
# 2. 50- Partially remote/hybird
# 3. 100 - Fully remote (more than 80%

# %%
# 4. Bar chart for remote ratio
plt.figure(figsize=(10, 6))
sns.countplot(x='remote_ratio', data=data1, palette='bright', edgecolor='0.2')
plt.title('Distribution of Remote Work Ratios')
plt.xlabel('Remote Work Ratio')
plt.ylabel('Count')
plt.show()

# %%
# 5. Company size Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='company_size', data=data1, palette='plasma')
plt.title('Distribution of Company Sizes')
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **Diagnostic Analysis**
# "Diagnostic analysis aims to understand the cause-and-effect relationships within the data. It investigates the factors or variables that contribute to specific outcomes or behaviors. Techniques such as regression analysis or correlation analysis are commonly used."

# %%
# 1. Correlation
correlation_matrix = data1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-12-eace89a6692a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data1.corr()

# %%
# 2. Scatter plot with regression line for salary vs. remote work ratio
plt.figure(figsize=(12, 6))
sns.regplot(x='remote_ratio', y='salary', data=data1, scatter_kws={'s': 30}, line_kws={'color': 'red'})
plt.title('Salary vs. Remote Work Ratio')
plt.xlabel('Remote Work Ratio')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
#  ### This visual explains how the 'remote_ratio' variable is related to the 'salary' variable. The red regression line provides an estimate of the linear relationship between these two variables. The scatter points show individual data points for each observation

# %%
# 3. Distribution of skills
skills_columns = ['Python', 'SQL', 'Tableau', 'AWS', 'PyTorch']

fig, axes = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle('Distribution of Skills', fontsize=16)


axes = axes.flatten()

for i, skill in enumerate(skills_columns):
    skill_counts = data1[skill].value_counts()
    axes[i].pie(skill_counts, labels=skill_counts.index, autopct='%1.1f%%', startangle=90)
    axes[i].set_title(f'Distribution of {skill} Skills')

plt.show()

# %%
# 4. Comparision of Skills Across Experience Levels
skills_columns = ['Python', 'SQL', 'Tableau', 'AWS', 'PyTorch']


fig, axes = plt.subplots(1, 5, figsize=(20, 6), sharey=True)
fig.suptitle('Comparison of Skills Across Experience Levels', fontsize=16)

for i, skill in enumerate(skills_columns):
    sns.countplot(y='experience_level', hue=skill, data=data1, ax=axes[i], palette='Spectral', edgecolor='0.2')
    axes[i].set_title(f'{skill} Skills')
    axes[i].set_xlabel('Count')
    axes[i].set_ylabel('Experience Level')


plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %% [markdown]
# ## Key Takeaways
#
# Please write a few bullet points (4-6) that describe the major conclusions you made about your dataset based on your analysis above.
#
# 1. Python is the most prevalent skill among the surveyed individuals, followed closely by SQL.
# 2. Larger companies (more than 250 employees) tend to have a higher proportion of individuals with AWS skills, possibly reflecting the demand for cloud expertise in larger organizations.
# 3. Business Analyst roles show a higher prevalence of Tableau skills, indicating a specific tool focus for this job title.
# 4. Senior-level roles show a more balanced distribution across various skills, with AWS being relatively more common.
# 5. The dataset indicates a significant portion of individuals working in fully remote positions, particularly in roles requiring Python and AWS skills.

# %% [markdown]
# ## Submission: Please submit .ipynb file to Canvas.
